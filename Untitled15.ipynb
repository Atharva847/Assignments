# %% [markdown]
# Q1: Explain the difference between simple linear regression and multiple linear regression. Provide an example of each.

# %%
'''
Simple Linear Regression involves modeling the relationship between a single independent variable 
𝑋
X and a dependent variable 
𝑌
Y. The relationship is expressed as:
𝑌
=
𝛽
0
+
𝛽
1
𝑋
+
𝜖
Y=β 
0
​
 +β 
1
​
 X+ϵ
where:

𝑌
Y is the dependent variable.
𝑋
X is the independent variable.
𝛽
0
β 
0
​
  is the intercept (the value of 
𝑌
Y when 
𝑋
=
0
X=0).
𝛽
1
β 
1
​
  is the slope (the change in 
𝑌
Y for a one-unit change in 
𝑋
X).
𝜖
ϵ is the error term (the difference between observed and predicted values).
Example: Predicting a person’s weight (
𝑌
Y) based on their height (
𝑋
X).

Multiple Linear Regression involves modeling the relationship between two or more independent variables and a dependent variable. 
The relationship is expressed as:
𝑌
=
𝛽
0
+
𝛽
1
𝑋
1
+
𝛽
2
𝑋
2
+
⋯
+
𝛽
𝑛
𝑋
𝑛
+
𝜖
Y=β 
0
​
 +β 
1
​
 X 
1
​
 +β 
2
​
 X 
2
​
 +⋯+β 
n
​
 X 
n
​
 +ϵ
where:

𝑌
Y is the dependent variable.
𝑋
1
,
𝑋
2
,
…
,
𝑋
𝑛
X 
1
​
 ,X 
2
​
 ,…,X 
n
​
  are the independent variables.
𝛽
0
β 
0
​
  is the intercept.
𝛽
1
,
𝛽
2
,
…
,
𝛽
𝑛
β 
1
​
 ,β 
2
​
 ,…,β 
n
​
  are the coefficients (slopes) for each independent variable.
𝜖
ϵ is the error term.
Example: Predicting a person’s weight (
𝑌
Y) based on their height (
𝑋
1
X 
1
​
 ) and age (
𝑋
2
X 
2
​
 ).
'''

# %% [markdown]
# Q2: Discuss the assumptions of linear regression. How can you check whether these assumptions hold in a given dataset?

# %%
'''
Assumptions of Linear Regression:

Linearity: The relationship between the independent variables and the dependent variable is linear.
Independence: Observations are independent of each other.
Homoscedasticity: The variance of errors is constant across all levels of the independent variables.
Normality of Errors: The errors (residuals) of the model are normally distributed.
No Multicollinearity: In multiple linear regression, the independent variables should not be highly correlated with each other.
Checking Assumptions:

Linearity: Use scatterplots of the independent variables vs. the dependent variable to check for linear relationships.
Independence: Check the data collection process to ensure independence; for time-series data, examine autocorrelation plots.
Homoscedasticity: Plot residuals vs. fitted values; the residuals should have a constant spread.
Normality of Errors: Use a Q-Q plot or a histogram of residuals to check for normality.
No Multicollinearity: Calculate the Variance Inflation Factor (VIF) for each independent variable; a VIF value greater than 10 may indicate
multicollinearity.
'''

# %% [markdown]
# Q3: How do you interpret the slope and intercept in a linear regression model? Provide an example using a real-world scenario.

# %%
'''
Interpretation:

Intercept (
𝛽
0
β 
0
​
 ): The expected value of 
𝑌
Y when all independent variables (
𝑋
1
,
𝑋
2
,
…
,
𝑋
𝑛
X 
1
​
 ,X 
2
​
 ,…,X 
n
​
 ) are zero. It represents the baseline level of 
𝑌
Y.
Slope (
𝛽
𝑖
β 
i
​
 ): The change in 
𝑌
Y for a one-unit change in 
𝑋
𝑖
X 
i
​
 , holding all other variables constant.
Example: Suppose we have a simple linear regression model predicting monthly sales (
𝑌
Y) based on advertising spend (
𝑋
X):
𝑌
=
2000
+
3
𝑋
Y=2000+3X

Intercept: When advertising spend is $0, the expected monthly sales are $2000.
Slope: For every additional dollar spent on advertising, monthly sales increase by $3.

'''

# %% [markdown]
# Q4: Explain the concept of gradient descent. How is it used in machine learning?

# %%
'''
Gradient Descent is an optimization algorithm used to minimize the cost (or loss) function in machine learning models.
It iteratively adjusts the model parameters to reduce the difference between predicted and actual values.

How It Works:

Start with an initial guess for the model parameters.
Compute the gradient (partial derivative) of the cost function with respect to each parameter.
Update the parameters by moving in the direction opposite to the gradient, scaled by a learning rate.
Repeat until the parameters converge to a minimum value of the cost function.
Use in Machine Learning: Gradient descent is widely used for training models like linear regression, logistic regression, and neural networks.
'''

# %% [markdown]
# Q5: Describe the multiple linear regression model. How does it differ from simple linear regression?

# %%
'''
Multiple Linear Regression Model:

It models the relationship between a dependent variable 
𝑌
Y and two or more independent variables 
𝑋
1
,
𝑋
2
,
…
,
𝑋
𝑛
X 
1
​
 ,X 
2
​
 ,…,X 
n
​
 .
The equation is:
𝑌
=
𝛽
0
+
𝛽
1
𝑋
1
+
𝛽
2
𝑋
2
+
⋯
+
𝛽
𝑛
𝑋
𝑛
+
𝜖
Y=β 
0
​
 +β 
1
​
 X 
1
​
 +β 
2
​
 X 
2
​
 +⋯+β 
n
​
 X 
n
​
 +ϵ
Difference from Simple Linear Regression:

Number of Independent Variables: Simple linear regression has one independent variable, while multiple linear regression has two or more.
Model Complexity: Multiple linear regression captures more complex relationships by considering the effect of multiple variables simultaneously.
'''

# %% [markdown]
# Q6: Explain the concept of multicollinearity in multiple linear regression. How can you detect and address this issue?

# %%
'''
Multicollinearity occurs when two or more independent variables in a multiple regression model are highly correlated, 
leading to unreliable estimates of the regression coefficients.

Detection:

Variance Inflation Factor (VIF): A VIF value greater than 10 indicates significant multicollinearity.
Correlation Matrix: A high correlation (close to ±1) between independent variables suggests multicollinearity.
Addressing Multicollinearity:

Remove Highly Correlated Variables: Drop one of the correlated variables.
Combine Variables: Create a new variable by combining the correlated variables (e.g., through PCA).
Regularization Techniques: Use ridge regression or Lasso to reduce the impact of multicollinearity.
'''

# %% [markdown]
# Q7: Describe the polynomial regression model. How is it different from linear regression?

# %%
'''
Polynomial Regression is a type of regression analysis where the relationship between the independent variable 
𝑋
X and the dependent variable 
𝑌
Y is modeled as an 
𝑛
nth-degree polynomial:
𝑌
=
𝛽
0
+
𝛽
1
𝑋
+
𝛽
2
𝑋
2
+
⋯
+
𝛽
𝑛
𝑋
𝑛
+
𝜖
Y=β 
0
​
 +β 
1
​
 X+β 
2
​
 X 
2
 +⋯+β 
n
​
 X 
n
 +ϵ

Difference from Linear Regression:

Model Complexity: Linear regression models a linear relationship, while polynomial regression models a non-linear relationship.
Curve Fitting: Polynomial regression can fit a curved line to the data, making it suitable for capturing more complex patterns.
'''

# %% [markdown]
# Q8: What are the advantages and disadvantages of polynomial regression compared to linear regression? In what situations would you prefer to use
# polynomial
# regression?

# %%
'''Advantages:

Better Fit for Non-linear Relationships: Polynomial regression can capture non-linear patterns that linear regression cannot.
Flexibility: The degree of the polynomial can be adjusted to fit the data more accurately.
Disadvantages:

Overfitting: Higher-degree polynomials may fit the training data too closely, leading to poor generalization on new data.
Complexity: As the degree increases, the model becomes more complex and harder to interpret.
When to Use Polynomial Regression:

When the relationship between the independent and dependent variables is non-linear.
When simple linear regression fails to capture the underlying pattern in the data.'''
